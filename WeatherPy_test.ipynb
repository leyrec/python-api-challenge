# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %%
#Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set counters for records and sets 
record_counter =0
set_counter =1

# Set lists for
longitude=[]
latitude =[]
temperature=[]
humidity=[]
wind=[]
clouds=[]
city_name =[]

print("Beginning Data Retrieval")
print("-------------------------------")

#Loop trhough the cities and store the targeted information and print results

for city in cities:
    
    try:
        response= requests.get(query_url + city).json()
        longitude.append(response["coord"]["lon"])
        latitude.append(response["coord"]["lat"])
        temperature.append(response["main"]["temp"])
        humidity.append(response["main"]["humidity"])
        wind.append(response["wind"]["speed"])
        clouds.append(response["clouds"]["all"])
        city_name.append(response["name"])
        if record_counter==50:
            record_counter=1
            set_counter+=1
        else:
            record_counter+=1
        
        print("Processing Record " + str(record_counter)+ " of Set "+ str(set_counter)+ "|"+ (city))


    except KeyError:
        print("City not found. Skipping....")

print("---------------------------------------")
print("Data Retrieval Completed")
print("---------------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1|chokurdakh
# Processing Record 2 of Set 1|lafiagi
# Processing Record 3 of Set 1|hithadhoo
# Processing Record 4 of Set 1|puerto ayora
# Processing Record 5 of Set 1|khatanga
# Processing Record 6 of Set 1|kodiak
# Processing Record 7 of Set 1|saraipali
# Processing Record 8 of Set 1|jamestown
# Processing Record 9 of Set 1|sabang
# Processing Record 10 of Set 1|sao joao da barra
# Processing Record 11 of Set 1|vaini
# Processing Record 12 of Set 1|atuona
# Processing Record 13 of Set 1|nuevo progreso
# Processing Record 14 of Set 1|buraydah
# Processing Record 15 of Set 1|honiara
# Processing Record 16 of Set 1|iqaluit
# Processing Record 17 of Set 1|busselton
# Processing Record 18 of Set 1|wick
# Processing Record 19 of Set 1|tasiilaq
# Processing Record 20 of Set 1|laranjeiras do sul
# Processing Record 21 of Set 1|vikulovo
# Processing Record 22 of Set 1|lasa
# Processing Record 23 of Set 1|hobart
# Processing Record 24 of Set 1|wangkui
# Processing Record 25 of Set 1|puerto narino
# Processing Record 26 of Set 1|chegdomyn
# Processing Record 27 of Set 1|jamtara
# City not found. Skipping....
# Processing Record 28 of Set 1|pisco
# Processing Record 29 of Set 1|mataura
# Processing Record 30 of Set 1|ushuaia
# Processing Record 31 of Set 1|araouane
# Processing Record 32 of Set 1|rikitea
# Processing Record 33 of Set 1|emerald
# Processing Record 34 of Set 1|domodossola
# Processing Record 35 of Set 1|clyde river
# Processing Record 36 of Set 1|chuy
# Processing Record 37 of Set 1|hirara
# Processing Record 38 of Set 1|valparaiso
# Processing Record 39 of Set 1|butaritari
# Processing Record 40 of Set 1|macenta
# Processing Record 41 of Set 1|avarua
# Processing Record 42 of Set 1|yellowknife
# Processing Record 43 of Set 1|carnarvon
# Processing Record 44 of Set 1|umm lajj
# Processing Record 45 of Set 1|padang
# Processing Record 46 of Set 1|sola
# Processing Record 47 of Set 1|arraial do cabo
# Processing Record 48 of Set 1|udachnyy
# Processing Record 49 of Set 1|port alfred
# Processing Record 50 of Set 1|hermanus
# Processing Record 1 of Set 2|punta arenas
# City not found. Skipping....
# Processing Record 2 of Set 2|san quintin
# Processing Record 3 of Set 2|manado
# Processing Record 4 of Set 2|kruisfontein
# Processing Record 5 of Set 2|vila
# Processing Record 6 of Set 2|khartoum
# Processing Record 7 of Set 2|vuktyl
# City not found. Skipping....
# Processing Record 8 of Set 2|mar del plata
# Processing Record 9 of Set 2|san cristobal
# City not found. Skipping....
# Processing Record 10 of Set 2|hobyo
# Processing Record 11 of Set 2|qaanaaq
# Processing Record 12 of Set 2|fortuna
# City not found. Skipping....
# Processing Record 13 of Set 2|cherskiy
# Processing Record 14 of Set 2|caravelas
# City not found. Skipping....
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 15 of Set 2|salym
# Processing Record 16 of Set 2|lavrentiya
# Processing Record 17 of Set 2|benjamin constant
# Processing Record 18 of Set 2|laurinburg
# Processing Record 19 of Set 2|jaisalmer
# Processing Record 20 of Set 2|castro
# Processing Record 21 of Set 2|new norfolk
# Processing Record 22 of Set 2|sao jose da coroa grande
# Processing Record 23 of Set 2|uray
# Processing Record 24 of Set 2|esperance
# Processing Record 25 of Set 2|weihe
# Processing Record 26 of Set 2|touros
# Processing Record 27 of Set 2|sosua
# Processing Record 28 of Set 2|kostomuksha
# Processing Record 29 of Set 2|tobermory
# Processing Record 30 of Set 2|la ronge
# Processing Record 31 of Set 2|san andres
# Processing Record 32 of Set 2|atar
# Processing Record 33 of Set 2|alice springs
# Processing Record 34 of Set 2|taoudenni
# Processing Record 35 of Set 2|fairbanks
# City not found. Skipping....
# Processing Record 36 of Set 2|luganville
# Processing Record 37 of Set 2|anloga
# Processing Record 38 of Set 2|mandleshwar
# Processing Record 39 of Set 2|albany
# Processing Record 40 of Set 2|russell
# Processing Record 41 of Set 2|torbay
# Processing Record 42 of Set 2|sao filipe
# Processing Record 43 of Set 2|winfield
# Processing Record 44 of Set 2|mamallapuram
# Processing Record 45 of Set 2|cape town
# Processing Record 46 of Set 2|port elizabeth
# Processing Record 47 of Set 2|corn island
# Processing Record 48 of Set 2|gorontalo
# Processing Record 49 of Set 2|waipawa
# Processing Record 50 of Set 2|nanortalik
# Processing Record 1 of Set 3|chicama
# Processing Record 2 of Set 3|havre-saint-pierre
# Processing Record 3 of Set 3|pevek
# Processing Record 4 of Set 3|taunggyi
# Processing Record 5 of Set 3|hasaki
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 6 of Set 3|bilma
# Processing Record 7 of Set 3|loiza
# Processing Record 8 of Set 3|lata
# City not found. Skipping....
# Processing Record 9 of Set 3|providencia
# Processing Record 10 of Set 3|agirish
# Processing Record 11 of Set 3|katobu
# Processing Record 12 of Set 3|teya
# Processing Record 13 of Set 3|wonthaggi
# Processing Record 14 of Set 3|cockburn town
# City not found. Skipping....
# Processing Record 15 of Set 3|vardo
# Processing Record 16 of Set 3|arlit
# Processing Record 17 of Set 3|sorong
# City not found. Skipping....
# Processing Record 18 of Set 3|ilinskiy
# City not found. Skipping....
# Processing Record 19 of Set 3|taksimo
# Processing Record 20 of Set 3|terrace bay
# Processing Record 21 of Set 3|muzhi
# Processing Record 22 of Set 3|christchurch
# Processing Record 23 of Set 3|guerrero negro
# Processing Record 24 of Set 3|tiksi
# Processing Record 25 of Set 3|traverse city
# Processing Record 26 of Set 3|nikolskoye
# Processing Record 27 of Set 3|ankazoabo
# Processing Record 28 of Set 3|georgetown
# Processing Record 29 of Set 3|cascais
# Processing Record 30 of Set 3|tautira
# Processing Record 31 of Set 3|saint george
# Processing Record 32 of Set 3|vila velha
# Processing Record 33 of Set 3|lebu
# Processing Record 34 of Set 3|khazar
# Processing Record 35 of Set 3|tura
# Processing Record 36 of Set 3|longyearbyen
# Processing Record 37 of Set 3|zhangye
# Processing Record 38 of Set 3|sioux lookout
# Processing Record 39 of Set 3|saint-philippe
# Processing Record 40 of Set 3|chapais
# Processing Record 41 of Set 3|yumen
# Processing Record 42 of Set 3|altamont
# Processing Record 43 of Set 3|muros
# Processing Record 44 of Set 3|talnakh
# Processing Record 45 of Set 3|east london
# City not found. Skipping....
# Processing Record 46 of Set 3|port macquarie
# Processing Record 47 of Set 3|norman wells
# Processing Record 48 of Set 3|khislavichi
# Processing Record 49 of Set 3|ducheng
# Processing Record 50 of Set 3|barrow
# Processing Record 1 of Set 4|hilo
# Processing Record 2 of Set 4|ovalle
# Processing Record 3 of Set 4|dandong
# Processing Record 4 of Set 4|alenquer
# Processing Record 5 of Set 4|cidreira
# Processing Record 6 of Set 4|katsuura
# Processing Record 7 of Set 4|ribeira grande
# Processing Record 8 of Set 4|taltal
# Processing Record 9 of Set 4|kovdor
# Processing Record 10 of Set 4|cabo san lucas
# Processing Record 11 of Set 4|waingapu
# City not found. Skipping....
# Processing Record 12 of Set 4|ocos
# Processing Record 13 of Set 4|provideniya
# Processing Record 14 of Set 4|shizunai
# Processing Record 15 of Set 4|taonan
# City not found. Skipping....
# Processing Record 16 of Set 4|sibolga
# Processing Record 17 of Set 4|bredasdorp
# City not found. Skipping....
# Processing Record 18 of Set 4|chake chake
# Processing Record 19 of Set 4|salta
# Processing Record 20 of Set 4|kapaa
# Processing Record 21 of Set 4|sorland
# Processing Record 22 of Set 4|puerto escondido
# Processing Record 23 of Set 4|nan
# Processing Record 24 of Set 4|tarakan
# Processing Record 25 of Set 4|thompson
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 26 of Set 4|faanui
# Processing Record 27 of Set 4|airai
# Processing Record 28 of Set 4|clonakilty
# Processing Record 29 of Set 4|calama
# Processing Record 30 of Set 4|saint-francois
# Processing Record 31 of Set 4|yaring
# Processing Record 32 of Set 4|huanren
# Processing Record 33 of Set 4|manokwari
# Processing Record 34 of Set 4|dikson
# Processing Record 35 of Set 4|tuktoyaktuk
# Processing Record 36 of Set 4|puerto del rosario
# Processing Record 37 of Set 4|komsomolskiy
# Processing Record 38 of Set 4|north bend
# Processing Record 39 of Set 4|lelesti
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 40 of Set 4|cap-aux-meules
# Processing Record 41 of Set 4|coquimbo
# Processing Record 42 of Set 4|effingham
# Processing Record 43 of Set 4|bethel
# Processing Record 44 of Set 4|egvekinot
# Processing Record 45 of Set 4|comarapa
# Processing Record 46 of Set 4|upata
# Processing Record 47 of Set 4|souillac
# Processing Record 48 of Set 4|shingu
# Processing Record 49 of Set 4|nicoya
# City not found. Skipping....
# Processing Record 50 of Set 4|luancheng
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 1 of Set 5|bertoua
# Processing Record 2 of Set 5|lucapa
# Processing Record 3 of Set 5|port hardy
# Processing Record 4 of Set 5|sinnamary
# Processing Record 5 of Set 5|salalah
# Processing Record 6 of Set 5|victor harbor
# Processing Record 7 of Set 5|leningradskiy
# Processing Record 8 of Set 5|vanimo
# Processing Record 9 of Set 5|zyryanka
# Processing Record 10 of Set 5|mehamn
# Processing Record 11 of Set 5|iwanai
# Processing Record 12 of Set 5|vohibinany
# Processing Record 13 of Set 5|leo
# Processing Record 14 of Set 5|tashigang
# Processing Record 15 of Set 5|aracati
# Processing Record 16 of Set 5|ambilobe
# Processing Record 17 of Set 5|matay
# Processing Record 18 of Set 5|mangrol
# City not found. Skipping....
# Processing Record 19 of Set 5|nuuk
# Processing Record 20 of Set 5|san patricio
# Processing Record 21 of Set 5|kyrylivka
# Processing Record 22 of Set 5|uvinza
# Processing Record 23 of Set 5|soe
# Processing Record 24 of Set 5|snezhnogorsk
# Processing Record 25 of Set 5|ilulissat
# Processing Record 26 of Set 5|kavaratti
# Processing Record 27 of Set 5|axim
# Processing Record 28 of Set 5|upernavik
# Processing Record 29 of Set 5|yendi
# Processing Record 30 of Set 5|bluff
# City not found. Skipping....
# Processing Record 31 of Set 5|pangnirtung
# Processing Record 32 of Set 5|namatanai
# City not found. Skipping....
# Processing Record 33 of Set 5|ahipara
# Processing Record 34 of Set 5|severo-kurilsk
# Processing Record 35 of Set 5|marsh harbour
# Processing Record 36 of Set 5|galle
# Processing Record 37 of Set 5|ixtapa
# Processing Record 38 of Set 5|umea
# Processing Record 39 of Set 5|camopi
# Processing Record 40 of Set 5|berdigestyakh
# Processing Record 41 of Set 5|klishkivtsi
# Processing Record 42 of Set 5|vanavara
# City not found. Skipping....
# Processing Record 43 of Set 5|praya
# Processing Record 44 of Set 5|payson
# Processing Record 45 of Set 5|sao geraldo do araguaia
# Processing Record 46 of Set 5|timizart
# Processing Record 47 of Set 5|nantucket
# Processing Record 48 of Set 5|camacupa
# Processing Record 49 of Set 5|linhares
# City not found. Skipping....
# Processing Record 50 of Set 5|solomenskoye
# Processing Record 1 of Set 6|riobamba
# Processing Record 2 of Set 6|college
# City not found. Skipping....
# Processing Record 3 of Set 6|jijiga
# Processing Record 4 of Set 6|isangel
# City not found. Skipping....
# Processing Record 5 of Set 6|cayenne
# Processing Record 6 of Set 6|mildura
# Processing Record 7 of Set 6|port keats
# Processing Record 8 of Set 6|igdir
# Processing Record 9 of Set 6|wageningen
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 10 of Set 6|ust-kuyga
# Processing Record 11 of Set 6|cururupu
# Processing Record 12 of Set 6|olinda
# Processing Record 13 of Set 6|bilibino
# Processing Record 14 of Set 6|neuquen
# Processing Record 15 of Set 6|ciro marina
# Processing Record 16 of Set 6|bandarbeyla
# Processing Record 17 of Set 6|puerto maldonado
# Processing Record 18 of Set 6|champerico
# City not found. Skipping....
# Processing Record 19 of Set 6|huadian
# City not found. Skipping....
# Processing Record 20 of Set 6|tenango
# Processing Record 21 of Set 6|sisimiut
# Processing Record 22 of Set 6|palmer
# Processing Record 23 of Set 6|mahebourg
# Processing Record 24 of Set 6|kalmunai
# Processing Record 25 of Set 6|juneau
# Processing Record 26 of Set 6|inta
# Processing Record 27 of Set 6|wahiawa
# Processing Record 28 of Set 6|karpathos
# Processing Record 29 of Set 6|teguldet
# Processing Record 30 of Set 6|stephenville
# Processing Record 31 of Set 6|chernyshevskiy
# Processing Record 32 of Set 6|los llanos de aridane
# Processing Record 33 of Set 6|ostrovnoy
# Processing Record 34 of Set 6|yanam
# Processing Record 35 of Set 6|berlevag
# Processing Record 36 of Set 6|surt
# Processing Record 37 of Set 6|menzelinsk
# Processing Record 38 of Set 6|atbasar
# Processing Record 39 of Set 6|okakarara
# Processing Record 40 of Set 6|yahotyn
# Processing Record 41 of Set 6|rafaela
# City not found. Skipping....
# Processing Record 42 of Set 6|kudahuvadhoo
# Processing Record 43 of Set 6|victoria
# City not found. Skipping....
# Processing Record 44 of Set 6|itarema
# Processing Record 45 of Set 6|yerbogachen
# Processing Record 46 of Set 6|frisco
# Processing Record 47 of Set 6|mount isa
# Processing Record 48 of Set 6|scheemda
# Processing Record 49 of Set 6|mandera
# Processing Record 50 of Set 6|ola
# Processing Record 1 of Set 7|wattegama
# Processing Record 2 of Set 7|botshabelo
# City not found. Skipping....
# Processing Record 3 of Set 7|wilmington
# Processing Record 4 of Set 7|saskylakh
# Processing Record 5 of Set 7|sioux falls
# Processing Record 6 of Set 7|portland
# Processing Record 7 of Set 7|belaya gora
# Processing Record 8 of Set 7|luwuk
# Processing Record 9 of Set 7|gazojak
# Processing Record 10 of Set 7|quatre cocos
# Processing Record 11 of Set 7|narsaq
# City not found. Skipping....
# Processing Record 12 of Set 7|herat
# Processing Record 13 of Set 7|comodoro rivadavia
# Processing Record 14 of Set 7|hofn
# Processing Record 15 of Set 7|chibuto
# Processing Record 16 of Set 7|ahuimanu
# Processing Record 17 of Set 7|alofi
# Processing Record 18 of Set 7|kahului
# Processing Record 19 of Set 7|farah
# Processing Record 20 of Set 7|tecolutla
# Processing Record 21 of Set 7|baykit
# Processing Record 22 of Set 7|batagay-alyta
# Processing Record 23 of Set 7|ca mau
# Processing Record 24 of Set 7|rosetta
# Processing Record 25 of Set 7|almaznyy
# Processing Record 26 of Set 7|moranbah
# Processing Record 27 of Set 7|dodoma
# Processing Record 28 of Set 7|rinteln
# Processing Record 29 of Set 7|choya
# Processing Record 30 of Set 7|verkhoyansk
# Processing Record 31 of Set 7|rawson
# Processing Record 32 of Set 7|tuatapere
# Processing Record 33 of Set 7|vila franca do campo
# Processing Record 34 of Set 7|northam
# City not found. Skipping....
# Processing Record 35 of Set 7|porto novo
# City not found. Skipping....
# Processing Record 36 of Set 7|carpinteria
# Processing Record 37 of Set 7|aklavik
# Processing Record 38 of Set 7|takoradi
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 39 of Set 7|jiwani
# Processing Record 40 of Set 7|sistranda
# Processing Record 41 of Set 7|bonavista
# Processing Record 42 of Set 7|muscat
# Processing Record 43 of Set 7|kutum
# Processing Record 44 of Set 7|nioro
# Processing Record 45 of Set 7|katangli
# Processing Record 46 of Set 7|constitucion
# City not found. Skipping....
# Processing Record 47 of Set 7|geraldton
# Processing Record 48 of Set 7|praia da vitoria
# Processing Record 49 of Set 7|victoria point
# Processing Record 50 of Set 7|nosy varika
# Processing Record 1 of Set 8|elos
# Processing Record 2 of Set 8|naduvattam
# Processing Record 3 of Set 8|tromso
# Processing Record 4 of Set 8|yulara
# Processing Record 5 of Set 8|mahajanga
# Processing Record 6 of Set 8|kadarkut
# Processing Record 7 of Set 8|codrington
# Processing Record 8 of Set 8|ewa beach
# Processing Record 9 of Set 8|kysyl-syr
# Processing Record 10 of Set 8|port augusta
# City not found. Skipping....
# Processing Record 11 of Set 8|bataipora
# Processing Record 12 of Set 8|homer
# Processing Record 13 of Set 8|zhezkazgan
# Processing Record 14 of Set 8|novorozhdestvenskaya
# Processing Record 15 of Set 8|khanu woralaksaburi
# Processing Record 16 of Set 8|aksu
# Processing Record 17 of Set 8|arauco
# Processing Record 18 of Set 8|aykhal
# Processing Record 19 of Set 8|qena
# Processing Record 20 of Set 8|mount gambier
# Processing Record 21 of Set 8|ambovombe
# Processing Record 22 of Set 8|izazi
# City not found. Skipping....
# Processing Record 23 of Set 8|mazagao
# Processing Record 24 of Set 8|miles city
# Processing Record 25 of Set 8|vostok
# Processing Record 26 of Set 8|mareeba
# City not found. Skipping....
# Processing Record 27 of Set 8|camacha
# City not found. Skipping....
# Processing Record 28 of Set 8|mogocha
# Processing Record 29 of Set 8|sitka
# Processing Record 30 of Set 8|laguna
# Processing Record 31 of Set 8|lorengau
# Processing Record 32 of Set 8|elliot lake
# Processing Record 33 of Set 8|gewane
# Processing Record 34 of Set 8|imeni zhelyabova
# Processing Record 35 of Set 8|karratha
# Processing Record 36 of Set 8|bloomfield
# Processing Record 37 of Set 8|talaya
# Processing Record 38 of Set 8|limon
# Processing Record 39 of Set 8|te anau
# Processing Record 40 of Set 8|coulommiers
# Processing Record 41 of Set 8|songea
# Processing Record 42 of Set 8|grindavik
# Processing Record 43 of Set 8|price
# Processing Record 44 of Set 8|deputatskiy
# City not found. Skipping....
# Processing Record 45 of Set 8|montague
# Processing Record 46 of Set 8|kang
# Processing Record 47 of Set 8|luderitz
# Processing Record 48 of Set 8|aleksandrov gay
# Processing Record 49 of Set 8|carutapera
# Processing Record 50 of Set 8|westport
# Processing Record 1 of Set 9|charlottetown
# Processing Record 2 of Set 9|quimper
# Processing Record 3 of Set 9|severobaykalsk
# Processing Record 4 of Set 9|osinovo
# City not found. Skipping....
# Processing Record 5 of Set 9|saint-augustin
# Processing Record 6 of Set 9|igarka
# Processing Record 7 of Set 9|sindor
# Processing Record 8 of Set 9|paamiut
# Processing Record 9 of Set 9|znamensk
# Processing Record 10 of Set 9|killam
# City not found. Skipping....
# Processing Record 11 of Set 9|haysville
# Processing Record 12 of Set 9|valdosta
# Processing Record 13 of Set 9|bathsheba
# Processing Record 14 of Set 9|nanakuli
# Processing Record 15 of Set 9|broken hill
# Processing Record 16 of Set 9|bambous virieux
# Processing Record 17 of Set 9|kalengwa
# Processing Record 18 of Set 9|itapetinga
# Processing Record 19 of Set 9|soligalich
# Processing Record 20 of Set 9|beyneu
# Processing Record 21 of Set 9|flin flon
# Processing Record 22 of Set 9|muriwai beach
# Processing Record 23 of Set 9|coihaique
# City not found. Skipping....
# Processing Record 24 of Set 9|podhum
# Processing Record 25 of Set 9|gat
# Processing Record 26 of Set 9|sobolevo
# Processing Record 27 of Set 9|kapuskasing
# City not found. Skipping....
# Processing Record 28 of Set 9|dingle
# Processing Record 29 of Set 9|kavieng
# Processing Record 30 of Set 9|alta floresta
# Processing Record 31 of Set 9|cap malheureux
# Processing Record 32 of Set 9|tymovskoye
# Processing Record 33 of Set 9|tucumcari
# Processing Record 34 of Set 9|lompoc
# Processing Record 35 of Set 9|batemans bay
# Processing Record 36 of Set 9|zachary
# Processing Record 37 of Set 9|raudeberg
# Processing Record 38 of Set 9|dutse
# Processing Record 39 of Set 9|shetpe
# Processing Record 40 of Set 9|seoul
# Processing Record 41 of Set 9|haines junction
# Processing Record 42 of Set 9|mataram
# Processing Record 43 of Set 9|key biscayne
# Processing Record 44 of Set 9|tecpan
# Processing Record 45 of Set 9|gillette
# Processing Record 46 of Set 9|diamantino
# Processing Record 47 of Set 9|qiqihar
# Processing Record 48 of Set 9|bella vista
# Processing Record 49 of Set 9|marzuq
# City not found. Skipping....
# Processing Record 50 of Set 9|denpasar
# Processing Record 1 of Set 10|hervey bay
# Processing Record 2 of Set 10|killybegs
# Processing Record 3 of Set 10|kargasok
# Processing Record 4 of Set 10|winneba
# Processing Record 5 of Set 10|ruwi
# Processing Record 6 of Set 10|whitehorse
# Processing Record 7 of Set 10|bafq
# Processing Record 8 of Set 10|tezu
# Processing Record 9 of Set 10|lumphat
# City not found. Skipping....
# Processing Record 10 of Set 10|chapleau
# Processing Record 11 of Set 10|poum
# Processing Record 12 of Set 10|vao
# Processing Record 13 of Set 10|tortoli
# Processing Record 14 of Set 10|acapulco
# Processing Record 15 of Set 10|dong xoai
# Processing Record 16 of Set 10|shunyi
# Processing Record 17 of Set 10|mabaruma
# Processing Record 18 of Set 10|brae
# Processing Record 19 of Set 10|jinchang
# City not found. Skipping....
# Processing Record 20 of Set 10|gavrilovka vtoraya
# City not found. Skipping....
# Processing Record 21 of Set 10|ouesso
# Processing Record 22 of Set 10|fare
# City not found. Skipping....
# Processing Record 23 of Set 10|odessa
# Processing Record 24 of Set 10|saint-pierre
# Processing Record 25 of Set 10|broome
# Processing Record 26 of Set 10|shambu
# Processing Record 27 of Set 10|kalabo
# Processing Record 28 of Set 10|penzance
# City not found. Skipping....
# Processing Record 29 of Set 10|meulaboh
# Processing Record 30 of Set 10|bitung
# Processing Record 31 of Set 10|buta
# Processing Record 32 of Set 10|carupano
# Processing Record 33 of Set 10|mwene-ditu
# Processing Record 34 of Set 10|moose factory
# Processing Record 35 of Set 10|krasnovishersk
# Processing Record 36 of Set 10|nalut
# Processing Record 37 of Set 10|whitianga
# Processing Record 38 of Set 10|restrepo
# City not found. Skipping....
# Processing Record 39 of Set 10|batticaloa
# Processing Record 40 of Set 10|sohag
# Processing Record 41 of Set 10|kaitangata
# Processing Record 42 of Set 10|bomet
# City not found. Skipping....
# Processing Record 43 of Set 10|san carlos de bariloche
# Processing Record 44 of Set 10|zhigansk
# Processing Record 45 of Set 10|dukat
# Processing Record 46 of Set 10|guacimo
# Processing Record 47 of Set 10|dinagat
# Processing Record 48 of Set 10|pemba
# Processing Record 49 of Set 10|biharamulo
# Processing Record 50 of Set 10|calvinia
# Processing Record 1 of Set 11|villa sandino
# Processing Record 2 of Set 11|mindelo
# Processing Record 3 of Set 11|coolum beach
# Processing Record 4 of Set 11|kamenka
# Processing Record 5 of Set 11|shihezi
# Processing Record 6 of Set 11|nirmal
# Processing Record 7 of Set 11|marshall
# City not found. Skipping....
# Processing Record 8 of Set 11|ginda
# Processing Record 9 of Set 11|presidencia roque saenz pena
# Processing Record 10 of Set 11|antsohihy
# Processing Record 11 of Set 11|krasnyye chetai
# Processing Record 12 of Set 11|iki-burul
# Processing Record 13 of Set 11|southbridge
# Processing Record 14 of Set 11|colares
# Processing Record 15 of Set 11|leshukonskoye
# Processing Record 16 of Set 11|dauphin
# City not found. Skipping....
# Processing Record 17 of Set 11|ulladulla
# City not found. Skipping....
# Processing Record 18 of Set 11|methoni
# Processing Record 19 of Set 11|shima
# City not found. Skipping....
# Processing Record 20 of Set 11|plettenberg bay
# Processing Record 21 of Set 11|corinto
# Processing Record 22 of Set 11|tiarei
# Processing Record 23 of Set 11|verkhovazhye
# Processing Record 24 of Set 11|rocha
# Processing Record 25 of Set 11|eidfjord
# Processing Record 26 of Set 11|goderich
# Processing Record 27 of Set 11|panaba
# Processing Record 28 of Set 11|prien
# Processing Record 29 of Set 11|santander
# City not found. Skipping....
# Processing Record 30 of Set 11|ashqelon
# Processing Record 31 of Set 11|aitape
# Processing Record 32 of Set 11|naryan-mar
# City not found. Skipping....
# Processing Record 33 of Set 11|conakry
# Processing Record 34 of Set 11|ghogha
# Processing Record 35 of Set 11|chama
# Processing Record 36 of Set 11|cairns
# Processing Record 37 of Set 11|bambanglipuro
# Processing Record 38 of Set 11|makakilo city
# Processing Record 39 of Set 11|twin falls
# Processing Record 40 of Set 11|piacabucu
# Processing Record 41 of Set 11|tyulgan
# Processing Record 42 of Set 11|ouallam
# Processing Record 43 of Set 11|ishigaki
# Processing Record 44 of Set 11|koutiala
# Processing Record 45 of Set 11|la romana
# Processing Record 46 of Set 11|rasra
# Processing Record 47 of Set 11|skibbereen
# Processing Record 48 of Set 11|razole
# Processing Record 49 of Set 11|kuleshovka
# Processing Record 50 of Set 11|bibiani
# Processing Record 1 of Set 12|severomuysk
# Processing Record 2 of Set 12|santa isabel do rio negro
# Processing Record 3 of Set 12|altay
# Processing Record 4 of Set 12|dhidhdhoo
# Processing Record 5 of Set 12|nemuro

# %% [markdown]
# ### Convert Raw Data to DataFrame
# #### Export the city data into a .csv.
# #### Display the DataFrame

# %%
# Create a Dataframe

city_data= pd.DataFrame({
                         "City": city_name
})
                        
]}

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
